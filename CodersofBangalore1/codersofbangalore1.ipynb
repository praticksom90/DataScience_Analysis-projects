# %%
with open("initialdata.txt", encoding='utf-8') as f:
    data = f.read()

# %%
data
# Out:
# "intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio\n\n_anujsinghal\n1,785 posts\n681K followers\n248 following\nAnuj Singhal\nDigital creator\nManaging Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul\n\ncode_flare\n165 posts\n216 followers\n10 following\nThe Journey Notebook | Travel | Food Blogger\nBlogger\n📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a\n\nbangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds\n\nsilkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants\n\nstartuphub_blr\n2,300 posts\n45K followers\n120 following\nStartup Hub Bangalore\nMedia\n🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter\n\nfoodie_in_kora\n890 posts\n5,600 followers\n400 following\nSneha | Bangalore Eats\nFood & Drink\nAagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123\n\nventure_vikram\n120 posts\n30K followers\n500 following\nVikram | Angel Investor\nInvestor\n💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck\n\npython_meetup_blr\n60 posts\n3,400 followers\n10 following\nPyBangalore Community\nCommunity\n🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore\n\nindiranagar_gossip\n300 posts\n8,900 followers\n20 following\nIndiranagar Spy\nPersonal Blog\nNot just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy\n\n\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️\n\n\n\n7iiuliiu\n1 post\n44 followers\n166 following\n︎𝐄︎ ♡︎.\n\n\nkatiasales2220\n107 posts\n219 followers\n1,401 following\nKatia Sales\nAlfabetização e Reforço Escolar\nEnsino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio"

# %%
chunks = data.split("\n\n") 
chunks = [c for c in chunks if len(c)>5]
chunks
# Out:
# ['intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio',
#  '_anujsinghal\n1,785 posts\n681K followers\n248 following\nAnuj Singhal\nDigital creator\nManaging Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul',
#  'code_flare\n165 posts\n216 followers\n10 following\nThe Journey Notebook | Travel | Food Blogger\nBlogger\n📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a',
#  'bangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds',
#  'silkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants',
#  'startuphub_blr\n2,300 posts\n45K followers\n120 following\nStartup Hub Bangalore\nMedia\n🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter',
#  "foodie_in_kora\n890 posts\n5,600 followers\n400 following\nSneha | Bangalore Eats\nFood & Drink\nAagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123",
#  'venture_vikram\n120 posts\n30K followers\n500 following\nVikram | Angel Investor\nInvestor\n💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck',
#  'python_meetup_blr\n60 posts\n3,400 followers\n10 following\nPyBangalore Community\nCommunity\n🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore',
#  'indiranagar_gossip\n300 posts\n8,900 followers\n20 following\nIndiranagar Spy\nPersonal Blog\nNot just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy',
#  '\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️',
#  '7iiuliiu\n1 post\n44 followers\n166 following\n︎𝐄︎ ♡︎.',
#  '\nkatiasales2220\n107 posts\n219 followers\n1,401 following\nKatia Sales\nAlfabetização e Reforço Escolar\nEnsino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio']

# %%
def parse_chunk(chunk): 
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",", ""))
        no_of_followers = float(sep_chunk[2].split(" follower")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000000)
        else:
            no_of_followers = int(no_of_followers)
             

    
        no_of_following = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000000)
        else:
            no_of_following = int(no_of_following)

            
        name = sep_chunk[4]
        if(len(sep_chunk)> 5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
        # print(username, no_of_posts, no_of_followers, no_of_following, name, type_of_page, bio, sep="\n")
        return {"username": username, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers, 
                "no_of_following": no_of_following, "name": name, "type_of_page": type_of_page, "bio": bio}

    
# print(parse_chunk(chunks[0]))

# %%
print(parse_chunk(chunks[0]))
# Out:
# {'username': 'intaglobal', 'no_of_posts': 1946, 'no_of_followers': '6,851 followers', 'no_of_following': '262 following', 'name': 'INTA', 'type_of_page': 'Nonprofit organization', 'bio': 'The association of ™ professionals.\ninta.campsite.bio'}

# %%
# all_chunks = [] 
# for chunk in chunks:  
#     print(f"The chunk is: {chunk}")
#     parsed_chunk = parse_chunk(chunk)
#     all_chunks.append(parsed_chunk)
# print(all_chunks)
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post)
# Out:
# The chunk is: intaglobal
# 1,946 posts
# 6,851 followers
# 262 following
# INTA
# Nonprofit organization
# The association of ™ professionals.
# inta.campsite.bio
# The chunk is: _anujsinghal
# 1,785 posts
# 681K followers
# 248 following
# Anuj Singhal
# Digital creator
# Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India
# Let’s talk about finance and life
# Contact: Singhalanuj1010@gmail.com
# hindi.cnbctv18.com/market-gurukul
# The chunk is: code_flare
# 165 posts
# 216 followers
# 10 following
# The Journey Notebook | Travel | Food Blogger
# Blogger
# 📍 Exploring places & phases of life 🌍
# .
# 🍵 From chai breaks to flight takes ✈️
# .
# 💫 Travel | Food | Daily life 🌸
# youtube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a
# The chunk is: bangalore_tech_bro
# 402 posts
# 12.5K followers
# 890 following
# Rahul | HSR Hustler
# Entrepreneur
# 🚀 Building the next Unicorn in Fintech
# ☕ 3rd Wave Coffee addict
# 💻 Python | React | AI
# 📍 HSR Layout, BLR
# linktr.ee/rahulbuilds
# The chunk is: silkboard_survivor
# 55 posts
# 1,200 followers
# 50 following
# Priya D.
# Public Figure
# 🚦 Stuck in traffic since 2019
# 🌧️ Loving the Bangalore weather, hating the cabs
# 🐍 Data Scientist by day, meme maker by night
# 📍 ORR
# bit.ly/my-traffic-rants
# The chunk is: startuphub_blr
# 2,300 posts
# 45K followers
# 120 following
# Startup Hub Bangalore
# Media
# 🦄 News from the Silicon Valley of India
# 📢 Funding alerts, Hiring trends, and Drama
# 📩 DM for features
# startuphub.blr/newsletter
# The chunk is: foodie_in_kora
# 890 posts
# 5,600 followers
# 400 following
# Sneha | Bangalore Eats
# Food & Drink
# Aagrah to Truffles 🍔
# Exploring Koramangala's cafe culture ☕
# DM for collabs
# https://www.google.com/search?q=zomato.com/users/sneha123
# The chunk is: venture_vikram
# 120 posts
# 30K followers
# 500 following
# Vikram | Angel Investor
# Investor
# 💸 Helping founders go 0 to 1
# Ex-Google, Ex-Amazon
# Investing in DeepTech & AI
# 📍 Indiranagar
# vikram.vc/pitch-deck
# The chunk is: python_meetup_blr
# 60 posts
# 3,400 followers
# 10 following
# PyBangalore Community
# Community
# 🐍 Weekly meetups for Pythonistas
# 📍 Cubbon Park | Sundays 4 PM
# Coding + Coffee + Community
# https://www.google.com/search?q=meetup.com/pybangalore
# The chunk is: indiranagar_gossip
# 300 posts
# 8,900 followers
# 20 following
# Indiranagar Spy
# Personal Blog
# Not just about 100ft Road 🤫
# Spilling tea on the best brunches and worst landlords
# Bengaluru
# https://www.google.com/search?q=medium.com/%40indiranagarspy
# The chunk is:
# ig_arbin07
# 50 posts
# 33 followers
# 30 following
# aarbinnn
# Gamer
# @dumb.arbin
# 🎮: Banana『juice (IGL🥷)
# Gamer never die, they just respawn🙂‍↔️
# The chunk is: 7iiuliiu
# 1 post
# 44 followers
# 166 following
# ︎𝐄︎ ♡︎.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 4
#       2 for chunk in chunks:
#       3     print(f"The chunk is: {chunk}")
# ----> 4     parsed_chunk = parse_chunk(chunk)
#       5     all_chunks.append(parsed_chunk)
#       6 print(all_chunks)
#
# Cell In[42], line 5, in parse_chunk(chunk)
#       3 sep_chunk = chunk.split('\n')
#       4 username = sep_chunk[0]
# ----> 5 no_of_posts = int(sep_chunk[1].split(" posts")[0].replace(",",""))
#       6 no_of_followers = sep_chunk[2]
#       7 no_of_following = sep_chunk[3]
#
# ValueError: invalid literal for int() with base 10: '1 post'

# %%
import json
s=json.dumps(all_chunks,indent=4)
print(s)
# Out:
# [
#     {
#         "username": "intaglobal",
#         "no_of_posts": 1946,
#         "no_of_followers": "6,851 followers",
#         "no_of_following": "262 following",
#         "name": "INTA",
#         "type_of_page": "Nonprofit organization",
#         "bio": "The association of \u2122 professionals.\ninta.campsite.bio"
#     },
#     {
#         "username": "_anujsinghal",
#         "no_of_posts": 1785,
#         "no_of_followers": "681K followers",
#         "no_of_following": "248 following",
#         "name": "Anuj Singhal",
#         "type_of_page": "Digital creator",
#         "bio": "Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet\u2019s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul"
#     },
#     {
#         "username": "code_flare",
#         "no_of_posts": 165,
#         "no_of_followers": "216 followers",
#         "no_of_following": "10 following",
#         "name": "The Journey Notebook | Travel | Food Blogger",
#         "type_of_page": "Blogger",
#         "bio": "\ud83d\udccd Exploring places & phases of life \ud83c\udf0d\n.\n\ud83c\udf75 From chai breaks to flight takes \u2708\ufe0f\n.\n\ud83d\udcab Travel | Food | Daily life \ud83c\udf38\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a"
#     },
#     {
#         "username": "bangalore_tech_bro",
#         "no_of_posts": 402,
#         "no_of_followers": "12.5K followers",
#         "no_of_following": "890 following",
#         "name": "Rahul | HSR Hustler",
#         "type_of_page": "Entrepreneur",
#         "bio": "\ud83d\ude80 Building the next Unicorn in Fintech\n\u2615 3rd Wave Coffee addict\n\ud83d\udcbb Python | React | AI\n\ud83d\udccd HSR Layout, BLR\nlinktr.ee/rahulbuilds"
#     },
#     {
#         "username": "silkboard_survivor",
#         "no_of_posts": 55,
#         "no_of_followers": "1,200 followers",
#         "no_of_following": "50 following",
#         "name": "Priya D.",
#         "type_of_page": "Public Figure",
#         "bio": "\ud83d\udea6 Stuck in traffic since 2019\n\ud83c\udf27\ufe0f Loving the Bangalore weather, hating the cabs\n\ud83d\udc0d Data Scientist by day, meme maker by night\n\ud83d\udccd ORR\nbit.ly/my-traffic-rants"
#     },
#     {
#         "username": "startuphub_blr",
#         "no_of_posts": 2300,
#         "no_of_followers": "45K followers",
#         "no_of_following": "120 following",
#         "name": "Startup Hub Bangalore",
#         "type_of_page": "Media",
#         "bio": "\ud83e\udd84 News from the Silicon Valley of India\n\ud83d\udce2 Funding alerts, Hiring trends, and Drama\n\ud83d\udce9 DM for features\nstartuphub.blr/newsletter"
#     },
#     {
#         "username": "foodie_in_kora",
#         "no_of_posts": 890,
#         "no_of_followers": "5,600 followers",
#         "no_of_following": "400 following",
#         "name": "Sneha | Bangalore Eats",
#         "type_of_page": "Food & Drink",
#         "bio": "Aagrah to Truffles \ud83c\udf54\nExploring Koramangala's cafe culture \u2615\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"
#     },
#     {
#         "username": "venture_vikram",
#         "no_of_posts": 120,
#         "no_of_followers": "30K followers",
#         "no_of_following": "500 following",
#         "name": "Vikram | Angel Investor",
#         "type_of_page": "Investor",
#         "bio": "\ud83d\udcb8 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n\ud83d\udccd Indiranagar\nvikram.vc/pitch-deck"
#     },
#     {
#         "username": "python_meetup_blr",
#         "no_of_posts": 60,
#         "no_of_followers": "3,400 followers",
#         "no_of_following": "10 following",
#         "name": "PyBangalore Community",
#         "type_of_page": "Community",
#         "bio": "\ud83d\udc0d Weekly meetups for Pythonistas\n\ud83d\udccd Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore"
#     },
#     {
#         "username": "indiranagar_gossip",
#         "no_of_posts": 300,
#         "no_of_followers": "8,900 followers",
#         "no_of_following": "20 following",
#         "name": "Indiranagar Spy",
#         "type_of_page": "Personal Blog",
#         "bio": "Not just about 100ft Road \ud83e\udd2b\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy"
#     },
#     {
#         "username": "ig_arbin07",
#         "no_of_posts": 50,
#         "no_of_followers": "33 followers",
#         "no_of_following": "30 following",
#         "name": "aarbinnn",
#         "type_of_page": "Gamer",
#         "bio": "@dumb.arbin\n\ud83c\udfae: Banana\u300ejuice (IGL\ud83e\udd77)\nGamer never die, they just respawn\ud83d\ude42\u200d\u2194\ufe0f"
#     }
# ]

# %%
all_chunks = [] 
for chunk in chunks:  
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 all_chunks = []
#       2 for chunk in chunks:
# ----> 3     parsed_chunk = parse_chunk(chunk)
#       4     all_chunks.append(parsed_chunk)
#       5 print(all_chunks)
#
# Cell In[42], line 5, in parse_chunk(chunk)
#       3 sep_chunk = chunk.split('\n')
#       4 username = sep_chunk[0]
# ----> 5 no_of_posts = int(sep_chunk[1].split(" posts")[0].replace(",",""))
#       6 no_of_followers = sep_chunk[2]
#       7 no_of_following = sep_chunk[3]
#
# ValueError: invalid literal for int() with base 10: '1 post'

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': '45K followers', 'no_of_following': '120 following', 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk
print(chunk_with_max_followers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 max = 0
#       2 for chunk in all_chunks:
# ----> 3     if(max < chunk['no_of_followers']):
#       4         max = chunk['no_of_followers']
#       5         chunk_with_max_followers = chunk
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_following']):
        max = chunk['no_of_following']
        chunk_with_max_following = chunk
print(chunk_with_max_following)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 max = 0
#       2 for chunk in all_chunks:
# ----> 3     if(max < chunk['no_of_following']):
#       4         max = chunk['no_of_following']
#       5         chunk_with_max_following = chunk
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(categories, len(categories))
# Out:
# {'Public Figure', 'Personal Blog', 'Gamer', 'Digital creator', 'Blogger', 'Community', 'Media', 'Entrepreneur', 'Food & Drink', 'Investor', 'Nonprofit organization'} 11
